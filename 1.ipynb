# %%
# import pandas as pd
# import pandas ad pdimport pandas as pd
# import json 
# from matplotlib import pyplot as plt
# # import matplotlib.pyplot as plt
# df = pd.read_csv("")
# df = df.to_csv("")
# b

# %%
import pandas as pd
D = {'Nghề':['Kế toán','Kinh doanh','Tiếp thị'],'Lương':[2000, 2100, 1900]}
df = pd.DataFrame(D)
print(df)

# %%
import pandas as pd
import numpy as np
dict = {0 : 'Kế toán', 1 : 'Kinh doanh', 2 : 'Tiếp thị'}
df=pd.Series(dict)
print(df)

# %%
import pandas as pd
tup = [("di choi",1),("di hoc",2)]
df = pd.DataFrame(tup,columns=["di dau","gia tri"])
print(df)

# %%
import pandas as pd
import numpy as np
arr = np.array([1,2,3,4,5,6])
print(pd.Series(arr))

# %%
import pandas as pd
ser = pd.Series(10,index = [1,2,3,4,5,6])
print(ser)

# %%
import pandas as pd
df = pd.read_csv("FoodPrice_in_Turkey.csv")
row = df.shape[0]
column = df.shape[1]
print(row,column)

print(df.describe())
print(df.info())

# %%
import pandas as pd
df = pd.read_csv("FoodPrice_in_Turkey.csv")
name = df.columns
print(df.columns)
print(df.dtypes)
# Out:
# Index(['Place', 'ProductId', 'ProductName', 'UmId', 'UmName', 'Month', 'Year',
#        'Price'],
#       dtype='object')
# Place           object
# ProductId        int64
# ProductName     object
# UmId             int64
# UmName          object
# Month            int64
# Year             int64
# Price          float64
# dtype: object

# %%
import pandas as pd
df = pd.read_csv("FoodPrice_in_Turkey.csv")
print(df.head())
# Out:
#               Place  ProductId    ProductName  UmId UmName  Month  Year  \
# 0  National Average         52  Rice - Retail     5     KG      5  2013
# 1  National Average         52  Rice - Retail     5     KG      6  2013
# 2  National Average         52  Rice - Retail     5     KG     11  2013
# 3  National Average         52  Rice - Retail     5     KG     12  2013
# 4  National Average         52  Rice - Retail     5     KG      1  2014
#
#     Price
# 0  4.4920
# 1  4.5786
# 2  4.7865
# 3  5.1337
# 4  5.5099

# %%
import pandas as pd
df = pd.read_csv("FoodPrice_in_Turkey.csv")
df = df.head()
print(df)
# Out:
#               Place  ProductId    ProductName  UmId UmName  Month  Year  \
# 0  National Average         52  Rice - Retail     5     KG      5  2013
# 1  National Average         52  Rice - Retail     5     KG      6  2013
# 2  National Average         52  Rice - Retail     5     KG     11  2013
# 3  National Average         52  Rice - Retail     5     KG     12  2013
# 4  National Average         52  Rice - Retail     5     KG      1  2014
#
#     Price
# 0  4.4920
# 1  4.5786
# 2  4.7865
# 3  5.1337
# 4  5.5099

# %%
import pandas as pd
df = pd.read_excel("house_price_dống-da.xlsx")
print(df)
# Out:
#                                                  title  \
# 0    Bán nhà Trần Quang Diệu mới coong đẹp 50m2x6 t...
# 1    Bán nhà mặt phố Tây Sơn - 6 tầng. Kinh doanh t...
# 2    Bán nhà số 36 Đoàn Kết - phố Khâm Thiên - Đống...
# 3    Bán nhà 6 tầng mới kinh doanh mặt ngõ 1194 Đườ...
# 4    Bán nhà mặt phố Thái Hà 70m2, 5 tầng, 4.5m mặt...
# ..                                                 ...
# 995  Bán nhà mặt phố Yên Lãng, Đống Đa, 65m2, 5T, 1...
# 996  Bán nhà 5 tầng đep MP Yên Lãng giá rẻ, DT 60m2...
# 997  MẶT PHỐ XÃ ĐÀN - KINH DOANH ĐỈNH CAO - 6 TẦNG ...
# 998  Bán nhà mặt hồ Văn Chương, Đống Đa 33m2, 6 tần...
# 999  Bán nhà 5 tầng MP Chùa Bộc hạ giá sốc, tử 58,6...
#
#                                                address   area    price  \
# 0    Đường Trần Quang Diệu, Phường Trung Liệt, Đốn...   50.0  14700.0
# 1    Đường Tây Sơn, Phường Trung Liệt, Đống Đa, Hà...   35.0  12500.0
# 2    Số 36 Đoàn Kết, Phố Khâm Thiên, Phường Thổ Qu...   57.0   4200.0
# ...

# %%
import pandas as pd
df = pd.read_excel("house_price_dống-da.xlsx")
# print(df.tail())
# print(df.head())
print(df.loc[1:3,["title"]])
print(df.iloc[1:3,0])
# Out:
#                                                title
# 1  Bán nhà mặt phố Tây Sơn - 6 tầng. Kinh doanh t...
# 2  Bán nhà số 36 Đoàn Kết - phố Khâm Thiên - Đống...
# 3  Bán nhà 6 tầng mới kinh doanh mặt ngõ 1194 Đườ...
# 1    Bán nhà mặt phố Tây Sơn - 6 tầng. Kinh doanh t...
# 2    Bán nhà số 36 Đoàn Kết - phố Khâm Thiên - Đống...
# Name: title, dtype: object
# C:\Users\DELL\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)

# %%
import pandas as pd
df = pd.read_html("https://en.wikipedia.org/wiki/List_of_sovereign_states_and_dependent_territories_in_North_America")
print(df)
# Out:
# [    Flag                     English short name  \
# 0    NaN               Antigua and Barbuda[n 1]
# 1    NaN                      Bahamas, The[n 1]
# 2    NaN                          Barbados[n 1]
# 3    NaN                       Belize[n 1][n 2]
# 4    NaN                            Canada[n 3]
# 5    NaN                        Costa Rica[n 2]
# 6    NaN                                   Cuba
# 7    NaN                          Dominica[n 1]
# 8    NaN                Dominican Republic[n 2]
# 9    NaN                       El Salvador[n 2]
# 10   NaN                           Grenada[n 1]
# 11   NaN                         Guatemala[n 2]
# 12   NaN                             Haiti[n 1]
# 13   NaN                          Honduras[n 2]
# 14   NaN                           Jamaica[n 1]
# 15   NaN                            Mexico[n 3]
# 16   NaN                         Nicaragua[n 2]
# 17   NaN                            Panama[n 2]
# ...
